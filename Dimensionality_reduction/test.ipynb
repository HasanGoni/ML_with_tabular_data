# %%
# Download zip file
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00372/HTRU2.zip

# Unzip it
# !unzip HTRU2.zip

# Remove the zip file
#!rm HTRU2.zip
# Out:
# --2022-03-10 07:54:38--  https://archive.ics.uci.edu/ml/machine-learning-databases/00372/HTRU2.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1563015 (1,5M) [application/x-httpd-php]
# Saving to: 'HTRU2.zip’
#
# HTRU2.zip           100%[===================>]   1,49M  49,6KB/s    in 33s
#
# 2022-03-10 07:55:12 (46,6 KB/s) - 'HTRU2.zip’ saved [1563015/1563015]
#
# Archive:  HTRU2.zip
# replace HTRU_2.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler
from sklearn.decomposition import PCA
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %%
# Load data into a pandas dataframe
data = pd.read_csv("HTRU_2.csv", names=['mean_ip', 'sd_ip', 'ec_ip', 
                                        'sw_ip', 'mean_dm', 'sd_dm', 
                                        'ec_dm', 'sw_dm', 'pulsar'])

# Take a look at the data
data.head()
# Out:
#       mean_ip      sd_ip     ec_ip     sw_ip   mean_dm      sd_dm      ec_dm  \
# 0  140.562500  55.683782 -0.234571 -0.699648  3.199833  19.110426   7.975532
# 1  102.507812  58.882430  0.465318 -0.515088  1.677258  14.860146  10.576487
# 2  103.015625  39.341649  0.323328  1.051164  3.121237  21.744669   7.735822
# 3  136.750000  57.178449 -0.068415 -0.636238  3.642977  20.959280   6.896499
# 4   88.726562  40.672225  0.600866  1.123492  1.178930  11.468720  14.269573
#
#         sw_dm  pulsar
# 0   74.242225       0
# 1  127.393580       0
# 2   63.171909       0
# 3   53.593661       0
# 4  252.567306       0

# %%
from preprocessing import scaling_df
from preprocessing import pca_show
from preprocessing import pca_of_data
from preprocessing import pca_of_data_2

# %%
df = pd.read_csv('HTRU_2.csv',
    names=['mean_ip', 'sd_ip', 'ec_ip', 
            'sw_ip', 'mean_dm', 'sd_dm', 
            'ec_dm', 'sw_dm', 'pulsar'])

# %%
dep_var = 'pulsar'

# %%
robust_data = scaling_df(
    csv_file_name='HTRU_2.csv',
    dep_var='pulsar',
    names=['mean_ip', 'sd_ip', 'ec_ip', 
            'sw_ip', 'mean_dm', 'sd_dm', 
            'ec_dm', 'sw_dm', 'pulsar'])

# %%
pca_show(robust_data)

# %%
df.head()
# Out:
#       mean_ip      sd_ip     ec_ip     sw_ip   mean_dm      sd_dm      ec_dm  \
# 0  140.562500  55.683782 -0.234571 -0.699648  3.199833  19.110426   7.975532
# 1  102.507812  58.882430  0.465318 -0.515088  1.677258  14.860146  10.576487
# 2  103.015625  39.341649  0.323328  1.051164  3.121237  21.744669   7.735822
# 3  136.750000  57.178449 -0.068415 -0.636238  3.642977  20.959280   6.896499
# 4   88.726562  40.672225  0.600866  1.123492  1.178930  11.468720  14.269573
#
#         sw_dm  pulsar
# 0   74.242225       0
# 1  127.393580       0
# 2   63.171909       0
# 3   53.593661       0
# 4  252.567306       0

# %%
pca_of_data_2(robust_data,
              pandas_df=df,
              dep_var=dep_var,
              no_of_components=2)

# %%
pca_of_data(robust_data,
            pandas_dataframe=df,
            dep_var=dep_var,
            no_component=3)

# %% [markdown]
# # Course 2 week 2 Feature selection notebook

# %%
df_b = pd.read_csv(
    'breast_cancer_data.csv'
)
df_b.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df_b.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
print(f'shape of the dataframe = {df.shape}')
# Out:
# shape of the dataframe = (17898, 9)

# %%
df_b.describe(include='all').T
# Out:
#                         count unique  top freq         mean          std  \
# id                        569    NaN  NaN  NaN  3.03718e+07  1.25021e+08
# diagnosis                 569      2    B  357          NaN          NaN
# radius_mean               569    NaN  NaN  NaN      14.1273      3.52405
# texture_mean              569    NaN  NaN  NaN      19.2896      4.30104
# perimeter_mean            569    NaN  NaN  NaN       91.969       24.299
# area_mean                 569    NaN  NaN  NaN      654.889      351.914
# smoothness_mean           569    NaN  NaN  NaN    0.0963603    0.0140641
# compactness_mean          569    NaN  NaN  NaN     0.104341    0.0528128
# concavity_mean            569    NaN  NaN  NaN    0.0887993    0.0797198
# concave points_mean       569    NaN  NaN  NaN    0.0489191    0.0388028
# symmetry_mean             569    NaN  NaN  NaN     0.181162    0.0274143
# fractal_dimension_mean    569    NaN  NaN  NaN    0.0627976   0.00706036
# ...

# %%
df_b.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...
